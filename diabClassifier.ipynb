# %%
###### Diabetes type2
#### Date of study : 20190206
import warnings
warnings.filterwarnings("ignore")

# %%
# packages
import xgboost as xgb
from sklearn.metrics import mean_squared_error as mse
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from imblearn.under_sampling import RandomUnderSampler
from datetime import datetime 
from sklearn import preprocessing as prep
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.model_selection import GridSearchCV

sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

# %%
# import data
df=pd.read_csv("diabetes_dataset.csv",sep="\t")
print("Columns: ",list(df.columns))
df.head()
# Out:
# Columns:  ['ident', 'grossesse', 'allaitementoui', 'ageq3', 'alcool', 'kcalsac', 'aphyq3', 'ATCDfamdiabQ8', 'diab', 'dt_diab', 'encoupleq1', 'etude', 'FDEP99', 'FRAP_I_NC', 'gpsang_rhe', 'hypertensionq3', 'hypolipi2', 'ttailleq4', 'imcq4', 'lateralite', 'statmeno_q3_cl', 'pattern_western', 'pattern_prudent', 'poidsnaiss', 'PRAL', 'ageregle', 'sommeil', 'tabacq3', 'transitq4']
#     ident  grossesse  allaitementoui      ageq3  alcool      kcalsac  aphyq3  \
# 0  100030          4               0  49.177276   11.88  1488.505569    19.5
# 1  100035          4               0  44.804928    0.67  2115.009831     4.5
# 2  100056          4               1  50.907598    3.62  2737.254258    10.5
# 3  100060          4               1  57.297741    0.00  2124.069913    13.5
# 4  100065          4               0  53.021218   21.07  1495.626383    21.0
#
#    ATCDfamdiabQ8  diab     dt_diab  ...  lateralite  statmeno_q3_cl  \
# 0              0     0         NaN  ...           0               0
# 1              0     0         NaN  ...           0               1
# 2              0     0         NaN  ...           0               0
# 3              1     0         NaN  ...           0               1
# 4              0     1  01/01/1996  ...           0               1
#
#    pattern_western  pattern_prudent  poidsnaiss       PRAL  ageregle  sommeil  \
# 0        -0.528209        -0.642924           3   2.688533         1        2
# 1        -0.533085         0.047411           1  -4.743413         1        2
# 2         0.651338         1.198105           1  -8.359993         2        3
# 3        -0.912994         1.228047           2  18.482343         1        2
# 4        -0.698218        -0.904501           9   3.074301         1        2
#
#    tabacq3  transitq4
# 0        3          4
# 1        3          1
# 2        3          1
# 3        3          1
# 4        3          1
#
# [5 rows x 29 columns]

# %%
print(df.describe())
print("each patient has one and only one diagnosis? :", len(identifiants.unique())==df.shape[0])
# Out:
#                ident     grossesse  allaitementoui         ageq3  \
# count   72890.000000  72890.000000    72890.000000  72890.000000
# mean   440516.993182      3.483345        0.618960     52.896163
# std    152276.841424      1.305707        0.485646      6.672942
# min    100030.000000      1.000000        0.000000     41.793292
# 25%    314293.500000      3.000000        0.000000     47.154004
# 50%    441488.500000      4.000000        1.000000     51.718001
# 75%    567666.750000      4.000000        1.000000     57.675565
# max    760068.000000      9.000000        1.000000     72.019165
#
#              alcool       kcalsac        aphyq3  ATCDfamdiabQ8          diab  \
# count  72890.000000  72890.000000  72371.000000   72890.000000  72890.000000
# mean      11.636730   2139.739228     29.480639       0.110632      0.051928
# std       14.087916    601.607620     35.184340       0.313679      0.221882
# min        0.000000     11.172228      0.000000       0.000000      0.000000
# 25%        1.600000   1737.014678     12.000000       0.000000      0.000000
# 50%        6.870000   2079.203337     21.000000       0.000000      0.000000
# 75%       16.570000   2470.337099     36.000000       0.000000      0.000000
# max      304.360000  11110.801314   1200.000000       1.000000      1.000000
#
#         encoupleq1  ...    lateralite  statmeno_q3_cl  pattern_western  \
# count  72890.00000  ...  72890.000000    72890.000000     71450.000000
# mean       1.13862  ...      1.812828        0.903677         0.000988
# std        1.61034  ...      3.538736        1.121425         0.998186
# min        0.00000  ...      0.000000        0.000000        -2.930531
# 25%        1.00000  ...      0.000000        0.000000        -0.709911
# 50%        1.00000  ...      0.000000        1.000000        -0.118908
# 75%        1.00000  ...      1.000000        2.000000         0.574606
# max        9.00000  ...      9.000000        9.000000         7.778702
#
#        pattern_prudent    poidsnaiss          PRAL      ageregle  \
# count     71450.000000  72890.000000  72890.000000  72890.000000
# mean         -0.005883      3.032213     -4.164402      1.686212
# std           0.994773      2.483571     18.031610      1.144519
# min          -3.280284      1.000000   -197.350869      1.000000
# 25%          -0.696494      2.000000    -14.026541      1.000000
# 50%          -0.126775      2.000000     -3.080340      2.000000
# 75%           0.554142      2.000000      7.052055      2.000000
# max           9.235585      9.000000    128.219807      9.000000
#
#             sommeil       tabacq3     transitq4
# count  72890.000000  72890.000000  72890.000000
# mean       3.378666      2.454562      2.542502
# std        2.821554      0.930813      2.542565
# min        1.000000      1.000000      1.000000
# 25%        2.000000      2.000000      1.000000
# 50%        2.000000      3.000000      1.000000
# 75%        3.000000      3.000000      3.000000
# max        9.000000      9.000000      9.000000
#
# [8 rows x 28 columns]
# each patient has one and only one diagnosis? : True

# %%
# Deal with datetime columns 
df['diagnosis_day'] =(pd.to_datetime("2019-02-06")-pd.to_datetime(df['dt_diab'])).dt.days
df['diagnosis_day'].value_counts()

# REMOVE IDENT
identifiants=df.ident
df.drop(columns=["ident"],axis=1,inplace=True)

# %%
# Deal with NAN values
print('Percentage of nan values %')
nan_data = df[ df.columns[df.isna().any()].tolist()].isna().sum(axis=0)/df.shape[0]*100
print(nan_data)
data = df.loc[:,df.isna().sum(axis=0)/df.shape[0]*100<90]
data.head()
# Out:
# Percentage of nan values %
# aphyq3              0.712032
# dt_diab            94.807244
# etude               3.409247
# FDEP99              5.760735
# ttailleq4          14.007408
# imcq4              11.911099
# pattern_western     1.975580
# pattern_prudent     1.975580
# diagnosis_day      94.807244
# dtype: float64
#    grossesse  allaitementoui      ageq3  alcool      kcalsac  aphyq3  \
# 0          4               0  49.177276   11.88  1488.505569    19.5
# 1          4               0  44.804928    0.67  2115.009831     4.5
# 2          4               1  50.907598    3.62  2737.254258    10.5
# 3          4               1  57.297741    0.00  2124.069913    13.5
# 4          4               0  53.021218   21.07  1495.626383    21.0
#
#    ATCDfamdiabQ8  diab  encoupleq1  etude  ...  lateralite  statmeno_q3_cl  \
# 0              0     0           1   13.0  ...           0               0
# 1              0     0           1    NaN  ...           0               1
# 2              0     0           1   13.0  ...           0               0
# 3              1     0           1   13.0  ...           0               1
# 4              0     1           1   13.0  ...           0               1
#
#    pattern_western  pattern_prudent  poidsnaiss       PRAL  ageregle  sommeil  \
# 0        -0.528209        -0.642924           3   2.688533         1        2
# 1        -0.533085         0.047411           1  -4.743413         1        2
# 2         0.651338         1.198105           1  -8.359993         2        3
# 3        -0.912994         1.228047           2  18.482343         1        2
# 4        -0.698218        -0.904501           9   3.074301         1        2
#
#    tabacq3  transitq4
# 0        3          4
# 1        3          1
# 2        3          1
# 3        3          1
# 4        3          1
#
# [5 rows x 27 columns]

# %%
# First analysis: Output distribution
fig= plt.figure(figsize=(5, 2))
sns.displot(data, x="diab")
plt.show()

# %% [markdown]
# we have a very unbalanced data so we have to keep that in mind for the training process

# %%
# Age and BMI DISTRIBUTION

sns.FacetGrid(data,hue="diab",size=5).map(sns.distplot,"ageq3")
sns.FacetGrid(data,hue="diab",size=5).map(sns.distplot,"aphyq3").add_legend()

# %%
sns.boxplot(data=data,y="ageq3",x="diab")
# Out:
# <AxesSubplot:xlabel='diab', ylabel='ageq3'>

# %%
# Type of diet impact when there is a history in the family
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 6))
sns.boxplot(data=data,y="pattern_western",x="diab",hue='ATCDfamdiabQ8',ax=axes[0])
sns.boxplot(data=data,y="pattern_prudent",x="diab",hue='ATCDfamdiabQ8',ax=axes[1])
fig.tight_layout()

# %%
sns.FacetGrid(data,hue="diab",size=5).map(sns.distplot,"pattern_prudent").add_legend()
sns.FacetGrid(data,hue="diab",size=5).map(sns.distplot,"pattern_western").add_legend()

# %%
# Deal with colinearity:
corr= data.corr()
cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_509687f4_6fc5_11ec_90f3_185680a06406 th {
#           font-size: 7pt;
#     }    #T_509687f4_6fc5_11ec_90f3_185680a06406 td {
#           padding: 0em 0em;
#     }    #T_509687f4_6fc5_11ec_90f3_185680a06406 th:hover {
#           font-size: 12pt;
#     }    #T_509687f4_6fc5_11ec_90f3_185680a06406 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }#T_509687f4_6fc5_11ec_90f3_185680a06406row0_col0,#T_509687f4_6fc5_11ec_90f3_185680a06406row1_col1,#T_509687f4_6fc5_11ec_90f3_185680a06406row2_col2,#T_509687f4_6fc5_11ec_90f3_185680a06406row3_col3,#T_509687f4_6fc5_11ec_90f3_185680a06406row4_col4,#T_509687f4_6fc5_11ec_90f3_185680a06406row5_col5,#T_509687f4_6fc5_11ec_90f3_185680a06406row6_col6,#T_509687f4_6fc5_11ec_90f3_185680a06406row7_col7,#T_509687f4_6fc5_11ec_90f3_185680a06406row8_col8,#T_509687f4_6fc5_11ec_90f3_185680a06406row9_col9,#T_509687f4_6fc5_11ec_90f3_185680a06406row10_col10,#T_509687f4_6fc5_11ec_90f3_185680a06406row11_col11,#T_509687f4_6fc5_11ec_90f3_185680a06406row12_col12,#T_509687f4_6fc5_11ec_90f3_185680a06406row13_col13,#T_509687f4_6fc5_11ec_90f3_185680a06406row14_col14,#T_509687f4_6fc5_11ec_90f3_185680a06406row15_col15,#T_509687f4_6fc5_11ec_90f3_185680a06406row16_col16,#T_509687f4_6fc5_11ec_90f3_185680a06406row17_col17,#T_509687f4_6fc5_11ec_90f3_185680a06406row18_col18,#T_509687f4_6fc5_11ec_90f3_185680a06406row19_col19,#T_509687f4_6fc5_11ec_90f3_185680a06406row20_col20,#T_509687f4_6fc5_11ec_90f3_185680a06406row21_col21,#T_509687f4_6fc5_11ec_90f3_185680a06406row22_col22,#T_509687f4_6fc5_11ec_90f3_185680a06406row23_col23,#T_509687f4_6fc5_11ec_90f3_185680a06406row24_col24,#T_509687f4_6fc5_11ec_90f3_185680a06406row25_col25,#T_509687f4_6fc5_11ec_90f3_185680a06406row26_col26{
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_509687f4_6fc5_11ec_90f3_185680a06406row0_col1{
#             background-color:  #f0e3e5;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_509687f4_6fc5_11ec_90f3_185680a06406row0_col2,#T_509687f4_6fc5_11ec_90f3_185680a06406row0_col17,#T_509687f4_6fc5_11ec_90f3_185680a06406row1_col11,#T_509687f4_6fc5_11ec_90f3_185680a06406row5_col0,#T_509687f4_6fc5_11ec_90f3_185680a06406row5_col6,#T_509687f4_6fc5_11ec_90f3_185680a06406row5_col21,#T_509687f4_6fc5_11ec_90f3_185680a06406row5_col25,#T_509687f4_6fc5_11ec_90f3_185680a06406row5_col26,#T_509687f4_6fc5_11ec_90f3_185680a06406row8_col5,#T_509687f4_6fc5_11ec_90f3_185680a06406row8_col6,#T_509687f4_6fc5_11ec_90f3_185680a06406row8_col19,#T_509687f4_6fc5_11ec_90f3_185680a06406row8_col22,#T_509687f4_6fc5_11ec_90f3_185680a06406row12_col14,#T_509687f4_6fc5_11ec_90f3_185680a06406row12_col16,#T_509687f4_6fc5_11ec_90f3_185680a06406row12_col25,#T_509687f4_6fc5_11ec_90f3_185680a06406row12_col26,#T_509687f4_6fc5_11ec_90f3_185680a06406row14_col3,#T_509687f4_6fc5_11ec_90f3_185680a06406row21_col1,#T_509687f4_6fc5_11ec_90f3_185680a06406row23_col5,#T_509687f4_6fc5_11ec_90f3_185680a06406row23_col24,#T_509687f4_6fc5_11ec_90f3_185680a06406row26_col1,#T_509687f4_6fc5_11ec_90f3_185680a06406row26_col3{
#             background-color:  #d94a67;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_509687f4_6fc5_11ec_90f3_185680a06406row0_col3,#T_509687f4_6fc5_11ec_90f3_185680a06406row1_col25,#T_509687f4_6fc5_11ec_90f3_185680a06406row12_col11,#T_509687f4_6fc5_11ec_90f3_185680a06406row14_col2,#T_509687f4_6fc5_11ec_90f3_185680a06406row14_col9,#T_509687f4_6fc5_11ec_90f3_185680a06406row14_col13,#T_509687f4_6fc5_11ec_90f3_185680a06406row18_col22,#T_509687f4_6fc5_11ec_90f3_185680a06406row23_col7,#T_509687f4_6fc5_11ec_90f3_185680a06406row23_col13,#T_509687f4_6fc5_11ec_90f3_185680a06406row23_col15,#T_509687f4_6fc5_11ec_90f3_185680a06406row23_col22,#T_509687f4_6fc5_11ec_90f3_185680a06406row26_col12,#T_509687f4_6fc5_11ec_90f3_185680a06406row26_col22,#T_509687f4_6fc5_11ec_90f3_185680a06406row26_col23{
#             background-color:  #d84462;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_509687f4_6fc5_11ec_90f3_185680a06406row0_col4,#T_509687f4_6fc5_11ec_90f3_185680a06406row0_col19,#T_509687f4_6fc5_11ec_90f3_185680a06406row0_col26,#T_509687f4_6fc5_11ec_90f3_185680a06406row2_col4,#T_509687f4_6fc5_11ec_90f3_185680a06406row3_col10,#T_509687f4_6fc5_11ec_90f3_185680a06406row7_col20,#T_509687f4_6fc5_11ec_90f3_185680a06406row9_col16,#T_509687f4_6fc5_11ec_90f3_185680a06406row11_col16,#T_509687f4_6fc5_11ec_90f3_185680a06406row13_col19,#T_509687f4_6fc5_11ec_90f3_185680a06406row16_col26,#T_509687f4_6fc5_11ec_90f3_185680a06406row18_col0,#T_509687f4_6fc5_11ec_90f3_185680a06406row18_col8{
#             background-color:  #dc5c76;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_509687f4_6fc5_11ec_90f3_185680a06406row0_col5,#T_509687f4_6fc5_11ec_90f3_185680a06406row1_col20,#T_509687f4_6fc5_11ec_90f3_185680a06406row1_col26,#T_509687f4_6fc5_11ec_90f3_185680a06406row5_col7,#T_509687f4_6fc5_11ec_90f3_185680a06406row7_col25,#T_509687f4_6fc5_11ec_90f3_185680a06406row12_col10,#T_509687f4_6fc5_11ec_90f3_185680a06406row12_col13,#T_509687f4_6fc5_11ec_90f3_185680a06406row12_col20,#T_509687f4_6fc5_11ec_90f3_185680a06406row21_col11,#T_509687f4_6fc5_11ec_90f3_185680a06406row23_col1,#T_509687f4_6fc5_11ec_90f3_185680a06406row23_col3,#T_509687f4_6fc5_11ec_90f3_185680a06406row23_col14,#T_509687f4_6fc5_11ec_90f3_185680a06406row23_col17,#T_509687f4_6fc5_11ec_90f3_185680a06406row23_col25,#T_509687f4_6fc5_11ec_90f3_185680a06406row23_col26,#T_509687f4_6fc5_11ec_90f3_185680a06406row26_col7,#T_509687f4_6fc5_11ec_90f3_185680a06406row26_col20{
#             background-color:  #d94865;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_509687f4_6fc5_11ec_90f3_185680a06406row0_col6,#T_509687f4_6fc5_11ec_90f3_185680a06406row0_col23,#T_509687f4_6fc5_11ec_90f3_185680a06406row5_col12,#T_509687f4_6fc5_11ec_90f3_185680a06406row7_col0,#T_509687f4_6fc5_11ec_90f3_185680a06406row7_col3,#T_509687f4_6fc5_11ec_90f3_185680a06406row7_col8,#T_509687f4_6fc5_11ec_90f3_185680a06406row7_col21,#T_509687f4_6fc5_11ec_90f3_185680a06406row8_col3,#T_509687f4_6fc5_11ec_90f3_185680a06406row8_col11,#T_509687f4_6fc5_11ec_90f3_185680a06406row8_col13,#T_509687f4_6fc5_11ec_90f3_185680a06406row8_col21,#T_509687f4_6fc5_11ec_90f3_185680a06406row12_col7,#T_509687f4_6fc5_11ec_90f3_185680a06406row12_col21,#T_509687f4_6fc5_11ec_90f3_185680a06406row14_col7,#T_509687f4_6fc5_11ec_90f3_185680a06406row18_col4,#T_509687f4_6fc5_11ec_90f3_185680a06406row23_col4,#T_509687f4_6fc5_11ec_90f3_185680a06406row23_col19,#T_509687f4_6fc5_11ec_90f3_185680a06406row26_col19{
#             background-color:  #da4b68;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_509687f4_6fc5_11ec_90f3_185680a06406row0_col7,#T_509687f4_6fc5_11ec_90f3_185680a06406row0_col11,#T_509687f4_6fc5_11ec_90f3_185680a06406row4_col18,#T_509687f4_6fc5_11ec_90f3_185680a06406row5_col1,#T_509687f4_6fc5_11ec_90f3_185680a06406row8_col7,#T_509687f4_6fc5_11ec_90f3_185680a06406row8_col14,#T_509687f4_6fc5_11ec_90f3_185680a06406row8_col18,#T_509687f4_6fc5_11ec_90f3_185680a06406row8_col26,#T_509687f4_6fc5_11ec_90f3_185680a06406row14_col1,#T_509687f4_6fc5_11ec_90f3_185680a06406row21_col25,#T_509687f4_6fc5_11ec_90f3_185680a06406row22_col2,#T_509687f4_6fc5_11ec_90f3_185680a06406row23_col12{
#             background-color:  #da4e6a;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_509687f4_6fc5_11ec_90f3_185680a06406row0_col8,#T_509687f4_6fc5_11ec_90f3_185680a06406row4_col12,#T_509687f4_6fc5_11ec_90f3_185680a06406row6_col18,#T_509687f4_6fc5_11ec_90f3_185680a06406row6_col21,#T_509687f4_6fc5_11ec_90f3_185680a06406row7_col19,#T_509687f4_6fc5_11ec_90f3_185680a06406row8_col0,#T_509687f4_6fc5_11ec_

# %%
### let's delete hypolipi2 sommeil kcalsac
data.drop(columns=["hypolipi2","sommeil", "kcalsac"],inplace=True)

# %%
# transform étude
sns.displot(data[data.diab==1], x="etude", hue="diab")
data['etude'] = pd.cut(data['etude'],3, labels=[1,2,3])
data['etude'] = data['etude'].astype("float")

# %%
# Find NUMERICAL and ORIDINAL/CATEGORICAL columns
cat_ord_cols = list(data.columns[data.nunique()<=9])
#cat_ord_cols.remove("etude")
cat_ord_cols.remove("diab")
num_cols = list(data.columns[data.nunique()>9])+["etude"]
## 
for col in data.columns:
    if col in cat_ord_cols :
        data[col].fillna(9,inplace=True)
    if col in num_cols :
        data[col].fillna(data[col].median(),inplace=True)

# %%
# One hot encode 
cat_cols = list(data.columns[data.nunique()<=3])
cat_cols.remove("diab")

for col in cat_cols:
    one_hot = pd.get_dummies(data[col],prefix=col)
    # Drop column B as it is now encoded
    data = data.drop(col,axis = 1)
    # Join the encoded df
    data = data.join(one_hot)

# %%
data.head()
# Out:
#    grossesse      ageq3  alcool  aphyq3  diab  etude    FDEP99  FRAP_I_NC  \
# 0          4  49.177276   11.88    19.5     0    3.0  0.019187   8.455401
# 1          4  44.804928    0.67     4.5     0    9.0  0.548716   8.113449
# 2          4  50.907598    3.62    10.5     0    3.0  0.236704  10.547431
# 3          4  57.297741    0.00    13.5     0    3.0  0.455917  13.310274
# 4          4  53.021218   21.07    21.0     1    3.0  0.561010  13.632363
#
#    gpsang_rhe  ttailleq4  ...  ATCDfamdiabQ8_0  ATCDfamdiabQ8_1  encoupleq1_0  \
# 0           4       79.0  ...                1                0             0
# 1           1       76.0  ...                1                0             0
# 2           4       73.0  ...                1                0             0
# 3           1       86.0  ...                0                1             0
# 4           1       86.0  ...                1                0             0
#
#    encoupleq1_1  encoupleq1_9  hypertensionq3_0  hypertensionq3_1  \
# 0             1             0                 1                 0
# 1             1             0                 1                 0
# 2             1             0                 1                 0
# 3             1             0                 0                 1
# 4             1             0                 0                 1
#
#    lateralite_0  lateralite_1  lateralite_9
# 0             1             0             0
# 1             1             0             0
# 2             1             0             0
# 3             1             0             0
# 4             1             0             0
#
# [5 rows x 31 columns]

# %%
# Train and test 
X_app,X_test,y_app,y_test = train_test_split(data.drop(columns=["diab"]), data['diab'],stratify=data['diab'], test_size=0.20,random_state=1)
print(y_app.value_counts())
print(y_test.value_counts())
# Out:
# 0    55284
# 1     3028
# Name: diab, dtype: int64
# 0    13821
# 1      757
# Name: diab, dtype: int64

# %%
# REG
scaler= prep.StandardScaler()
# Fit on train and apply it
X_train = scaler.fit_transform(X_app,y_train)
# Apply on test 
X_test = scaler.fit_transform(X_test)

# %%
# First baseline model 
LR = LogisticRegression()
LR.fit(X_train,y_train)
# Predict 
predictions = LR.predict(X_test)
# Use score method to get accuracy of model
score = LR.score(X_test, y_test)
print("Model's accuracy :",score)
cm = metrics.confusion_matrix(y_test, predictions)
print(metrics.classification_report(y_test, predictions))
# Out:
# Model's accuracy : 0.9488269995884209
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     13821
#            1       0.58      0.05      0.10       757
#
#     accuracy                           0.95     14578
#    macro avg       0.77      0.53      0.54     14578
# weighted avg       0.93      0.95      0.93     14578

# %%
plt.figure(figsize=(4,4))
sns.heatmap(cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15);

# %% [markdown]
# # Ensemble methods:
#       ## Bagging: Random forest
#       ## Bosting: XGBOOST

# %%
RF = RandomForestClassifier()
RF.fit(X_train,y_train)
# Predict 
predictions = RF.predict(X_test)
# Use score method to get accuracy of model
score = RF.score(X_test, y_test)
print("Model's accuracy :",score)
cm = metrics.confusion_matrix(y_test, predictions)
print(metrics.classification_report(y_test, predictions))
# Out:
# Model's accuracy : 0.9484154204966387
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     13821
#            1       0.59      0.02      0.04       757
#
#     accuracy                           0.95     14578
#    macro avg       0.77      0.51      0.51     14578
# weighted avg       0.93      0.95      0.93     14578

# %%
XG = xgb.XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')
XG.fit(X_train,y_train)
# Predict 
predictions = XG.predict(X_test)
# Use score method to get accuracy of model
score = XG.score(X_test, y_test)
print("Model's accuracy :",score)
cm = metrics.confusion_matrix(y_test, predictions)
print(metrics.classification_report(y_test, predictions))
# Out:
# Model's accuracy : 0.9475236657977775
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     13821
#            1       0.45      0.05      0.09       757
#
#     accuracy                           0.95     14578
#    macro avg       0.70      0.52      0.53     14578
# weighted avg       0.92      0.95      0.93     14578

# %% [markdown]
# # Undersampling

# %%
# Undersample
# Create an undersampler object
rus = RandomUnderSampler()
X_train, y_train= rus.fit_resample(X_app, y_app)
y_train.value_counts()

from imblearn.over_sampling import SMOTE

### oversample :
sm = SMOTE()
X_train, y_train=sm.fit_resample(X_app, y_app)
y_train.value_counts()
# Out:
# 1    55284
# 0    55284
# Name: diab, dtype: int64

# %%
X_app
# Out:
#        grossesse      ageq3  alcool  aphyq3  etude    FDEP99  FRAP_I_NC  \
# 6234           2  51.164956    7.98     6.0    3.0  0.197371  13.968389
# 22534          4  65.771389   28.93    10.5    3.0  1.484846   8.623653
# 72743          4  56.024641   24.10    42.0    3.0  0.635628  14.189002
# 64108          4  44.435318   19.88    22.5    3.0  0.236384  14.412255
# 36572          4  53.029432   11.95    12.0    3.0  0.244111  10.103692
# ...          ...        ...     ...     ...    ...       ...        ...
# 29587          5  57.913758   31.35     9.0    3.0  0.607443  18.965203
# 65819          3  57.234771   11.35    15.0    3.0 -0.906296  10.616146
# 48184          1  55.646817   11.58    24.0    3.0 -0.757133  11.609597
# 17791          2  45.467488    7.42    15.0    3.0 -0.415021  20.057975
# 41011          9  58.587269    0.60    10.5    1.0  1.637869   5.812949
#
#        gpsang_rhe  ttailleq4  imcq4  ...  ATCDfamdiabQ8_0  ATCDfamdiabQ8_1  \
# 6234            4       74.0  21.30  ...                1                0
# 22534           4       84.0  24.17  ...                1                0
# 72743           1       74.0  19.53  ...                1                0
# 64108           4       67.0  21.88  ...                1                0
# 36572           2       76.0  20.20  ...                1                0
# ...           ...        ...    ...  ...              ...              ...
# 29587           1       73.0  19.97  ...                1                0
# 65819           9       82.0  28.13  ...                0                1
# 48184           9       76.0  23.14  ...                1                0
# 17791           1       77.0  22.94  ...                1                0
# 41011           2       75.0  22.60  ...                1                0
#
#        encoupleq1_0  encoupleq1_1  encoupleq1_9  hypertensionq3_0  \
# 6234              0             1             0                 1
# 22534             0             1             0                 0
# 72743             0             1             0                 1
# 64108             0             1             0                 0
# 36572             0             1             0                 1
# ...             ...           ...           ...               ...
# 29587             0             1             0                 0
# 65819             0             1             0                 1
# 48184             1             0             0                 1
# 17791             0             1             0                 1
# 41011             1             0             0                 0
#
#        hypertensionq3_1  lateralite_0  lateralite_1  lateralite_9
# 6234                  0             1             0             0
# 22534                 1             1             0             0
# 72743                 0             1             0             0
# 64108                 1             0             0             1
# 36572                 0             1             0             0
# ...                 ...           ...           ...           ...
# 29587                 1             1             0             0
# 65819                 0             0             1             0
# 48184                 0             0             0             1
# 17791                 0             1             0             0
# 41011                 1             0             1             0
#
# [58312 rows x 30 columns]

# %%
# First baseline model 
LR = LogisticRegression()
LR.fit(X_train,y_train)
# Predict 
predictions = LR.predict(X_test)
# Use score method to get accuracy of model
score = LR.score(X_test, y_test)
print("Model's accuracy :",score)
cm = metrics.confusion_matrix(y_test, predictions)
print(metrics.classification_report(y_test, predictions))
plt.figure(figsize=(4,4))
sns.heatmap(cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15);
# Out:
# Model's accuracy : 0.8867471532446152
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94     13821
#            1       0.17      0.31      0.22       757
#
#     accuracy                           0.89     14578
#    macro avg       0.57      0.61      0.58     14578
# weighted avg       0.92      0.89      0.90     14578

# %%
rfc = RandomForestClassifier(n_jobs=-1,max_features= 'sqrt' ,n_estimators=50, oob_score = True)

param_grid = { 
    'n_estimators': [200, 700],
    'max_features': ['auto', 'sqrt', 'log2']
}

RF = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5,verbose =100 )
RF.fit(X_train,y_train)

# Predict 
predictions = RF.predict(X_test)
# Use score method to get accuracy of model
score = RF.score(X_test, y_test)
print("Model's accuracy :",score)
cm = metrics.confusion_matrix(y_test, predictions)
print(metrics.classification_report(y_test, predictions))
cm = metrics.confusion_matrix(y_test, predictions)
print(metrics.classification_report(y_test, predictions))
plt.figure(figsize=(4,4))
sns.heatmap(cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15);
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5; 1/6] START max_features=auto, n_estimators=200.........................
# [CV 1/5; 1/6] END max_features=auto, n_estimators=200;, score=0.873 total time=  24.3s
# [CV 2/5; 1/6] START max_features=auto, n_estimators=200.........................
# [CV 2/5; 1/6] END max_features=auto, n_estimators=200;, score=0.993 total time=  23.3s
# [CV 3/5; 1/6] START max_features=auto, n_estimators=200.........................
# [CV 3/5; 1/6] END max_features=auto, n_estimators=200;, score=0.994 total time=  19.5s
# [CV 4/5; 1/6] START max_features=auto, n_estimators=200.........................
# [CV 4/5; 1/6] END max_features=auto, n_estimators=200;, score=0.993 total time=  24.6s
# [CV 5/5; 1/6] START max_features=auto, n_estimators=200.........................
# [CV 5/5; 1/6] END max_features=auto, n_estimators=200;, score=0.994 total time=  24.3s
# [CV 1/5; 2/6] START max_features=auto, n_estimators=700.........................
# [CV 1/5; 2/6] END max_features=auto, n_estimators=700;, score=0.873 total time= 1.3min
# [CV 2/5; 2/6] START max_features=auto, n_estimators=700.........................
# [CV 2/5; 2/6] END max_features=auto, n_estimators=700;, score=0.994 total time= 1.4min
# [CV 3/5; 2/6] START max_features=auto, n_estimators=700.........................
# [CV 3/5; 2/6] END max_features=auto, n_estimators=700;, score=0.995 total time= 1.3min
# [CV 4/5; 2/6] START max_features=auto, n_estimators=700.........................
# [CV 4/5; 2/6] END max_features=auto, n_estimators=700;, score=0.993 total time= 1.3min
# [CV 5/5; 2/6] START max_features=auto, n_estimators=700.........................
# [CV 5/5; 2/6] END max_features=auto, n_estimators=700;, score=0.994 total time= 1.4min
# [CV 1/5; 3/6] START max_features=sqrt, n_estimators=200.........................
# [CV 1/5; 3/6] END max_features=sqrt, n_estimators=200;, score=0.874 total time=  21.9s
# [CV 2/5; 3/6] START max_features=sqrt, n_estimators=200.........................
# [CV 2/5; 3/6] END max_features=sqrt, n_estimators=200;, score=0.993 total time=  23.8s
# [CV 3/5; 3/6] START max_features=sqrt, n_estimators=200.........................
# [CV 3/5; 3/6] END max_features=sqrt, n_estimators=200;, score=0.995 total time=  23.1s
# [CV 4/5; 3/6] START max_features=sqrt, n_estimators=200.........................
# [CV 4/5; 3/6] END max_features=sqrt, n_estimators=200;, score=0.993 total time=  24.2s
# [CV 5/5; 3/6] START max_features=sqrt, n_estimators=200.........................
# [CV 5/5; 3/6] END max_features=sqrt, n_estimators=200;, score=0.994 total time=  26.3s
# [CV 1/5; 4/6] START max_features=sqrt, n_estimators=700.........................
# [CV 1/5; 4/6] END max_features=sqrt, n_estimators=700;, score=0.873 total time= 1.2min
# [CV 2/5; 4/6] START max_features=sqrt, n_estimators=700.........................
# [CV 2/5; 4/6] END max_features=sqrt, n_estimators=700;, score=0.994 total time= 1.3min
# [CV 3/5; 4/6] START max_features=sqrt, n_estimators=700.........................
# [CV 3/5; 4/6] END max_features=sqrt, n_estimators=700;, score=0.994 total time= 1.3min
# [CV 4/5; 4/6] START max_features=sqrt, n_estimators=700.........................
# [CV 4/5; 4/6] END max_features=sqrt, n_estimators=700;, score=0.993 total time= 1.3min
# [CV 5/5; 4/6] START max_features=sqrt, n_estimators=700.........................
# [CV 5/5; 4/6] END max_features=sqrt, n_estimators=700;, score=0.994 total time= 1.3min
# [CV 1/5; 5/6] START max_features=log2, n_estimators=200.........................
# [CV 1/5; 5/6] END max_features=log2, n_estimators=200;, score=0.874 total time=  22.9s
# [CV 2/5; 5/6] START max_features=log2, n_estimators=200.........................
# [CV 2/5; 5/6] END max_features=log2, n_estimators=200;, score=0.994 total time=  19.6s
# [CV 3/5; 5/6] START max_features=log2, n_estimators=200.........................
# [CV 3/5; 5/6] END max_features=log2, n_estimators=200;, score=0.994 total time=  21.2s
# [CV 4/5; 5/6] START max_features=log2, n_estimators=200.........................
# [CV 4/5; 5/6] END max_features=log2, n_estimators=200;, score=0.993 total time=  17.8s
# [CV 5/5; 5/6] START max_features=log2, n_estimators=200.........................
# [CV 5/5; 5/6] END max_features=log2, n_estimators=200;, score=0.994 total time=  18.2s
# [CV 1/5; 6/6] START max_features=log2, n_estimators=700.........................
# [CV 1/5; 6/6] END max_features=log2, n_estimators=700;, score=0.874 total time=  60.0s
# [CV 2/5; 6/6] START max_features=log2, n_estimators=700.........................
# [CV 2/5; 6/6] END max_features=log2, n_estimators=700;, score=0.994 total time= 1.0min
# [CV 3/5; 6/6] START max_features=log2, n_estimators=700.........................
# [CV 3/5; 6/6] END max_features=log2, n_estimators=700;, score=0.995 total time= 1.0min
# [CV 4/5; 6/6] START max_features=log2, n_estimators=700.........................
# [CV 4/5; 6/6] END max_features=log2, n_estimators=700;, score=0.993 total time= 1.1min
# [CV 5/5; 6/6] START max_features=log2, n_estimators=700.........................
# [CV 5/5; 6/6] END max_features=log2, n_estimators=700;, score=0.994 total time= 1.0min
# Model's accuracy : 0.9467005076142132
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     13821
#            1       0.39      0.05      0.09       757
#
#     accuracy                           0.95     14578
#    macro avg       0.67      0.52      0.53     14578
# weighted avg       0.92      0.95      0.93     14578
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     13821
#            1       0.39      0.05      0.09       757
#
#     accuracy                           0.95     14578
#    macro avg       0.67      0.52      0.53     14578
# weighted avg       0.92      0.95      0.93     14578

# %%
XG = xgb.XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')
XG.fit(X_train,y_train)
# Predict 
predictions = XG.predict(X_test)
# Use score method to get accuracy of model
score = XG.score(X_test, y_test)
print("Model's accuracy :",score)
cm = metrics.confusion_matrix(y_test, predictions)
print(metrics.classification_report(y_test, predictions))
plt.figure(figsize=(4,4))
sns.heatmap(cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15);
# Out:
# Model's accuracy : 0.6869255041843875
#               precision    recall  f1-score   support
#
#            0       0.97      0.69      0.81     13821
#            1       0.11      0.67      0.18       757
#
#     accuracy                           0.69     14578
#    macro avg       0.54      0.68      0.49     14578
# weighted avg       0.93      0.69      0.77     14578
